# %% [markdown]
# <a href="https://colab.research.google.com/github/Sifiso-Mazibuko/Pandas/blob/main/pandas_dataframe_practical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas DataFrame practical

# %% [markdown]
# ## Dictionary --> DataFrame

# %%
import pandas as pd

# %% [markdown]
# Anna is 8 years old and has a dog. Ben is 10 years old and has a cat. Chris is 12 years old and has a parrot. Dean is 7 years old and has a dog. Edward is 15 years old and has a goldfish
#
# Create a Pandas DataFrame named *df_from_dict* that lists the above information in three columns with headings "Name", "Age" and "Pet"

# %%
# enter code here
df_from_dict = {'Name':['Anna', 'Ben', 'Chris',' Dean', 'Edward'],
                'Age' :[8, 10, 12, 7, 15],
                'Pet' :['dog', 'cat', 'parrot', 'dog', 'goldfish']
                }

# %%
df_from_dict = pd.DataFrame(df_from_dict)

# %%
df_from_dict
# Out:
#      Name  Age       Pet
# 0    Anna    8       dog
# 1     Ben   10       cat
# 2   Chris   12    parrot
# 3    Dean    7       dog
# 4  Edward   15  goldfish

# %% [markdown]
# Determine Dean's pet by only using Pandas Dataframes commands

# %% [markdown]
# ## CSV / Excel sheet --> DataFrame

# %% [markdown]
# Create a folder named pandas_df_prac in your Drive.
# Upload the Excel sheet "sample_sales.xlsx" to that folder.
# Now mount your Google Drive and define a variable "file_path" that specifies the path to that Excel sheet

# %%
# enter code here
from google.colab from files
file_path = files.upload()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/pandas_df_prac/sample_sales.xlsx'

# %% [markdown]
# Create a dataframe **`df1`** from the first sheet of the "sample_sales.xlsx" Excel file.

# %%
df1=pd.read_excel(file_path)

# %%
# Out:
#                                Region                Country        Item Type  \
# 0                              Europe                 Russia  Office Supplies
# 1               Australia and Oceania                 Tuvalu        Baby Food
# 2                                   ~  Sao Tome and Principe           Fruits
# 3   Central America and the Caribbean                Grenada           Cereal
# 4                              Europe                 Russia  Office Supplies
# 5                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 6                  Sub-Saharan Africa                 Rwanda  Office Supplies
# 7               Australia and Oceania        Solomon Islands        Baby Food
# 8                  Sub-Saharan Africa                 Angola        Household
# 9                  Sub-Saharan Africa                 Angola        Household
# 10                 Sub-Saharan Africa                      ~       Vegetables
# ...

# %% [markdown]
# Create a dataframe **`df2`** from the second sheet of the Excel file.
# * Note that this dataset does not have any headings.
# * Add the same headings to this dataframe as in the first sheet, namely:
#
# "Region", "Country", "Item Type", "Order Priority", "Order Date", "Total Cost", "Total Profit"

# %%
second_path = '/content/drive/MyDrive/pandas_df_prac/sample_sales2.xlsx'

# %%
headings = ['Region', 'Country', 'Item Type', 'Order Priority', 'Order Date', 'Total Cost', 'Total Profit']
df2=pd.read_excel(second_path, sheet_name = 'Sample_Sales_2')
df2.head()
# Out:
#                          Europe   Monaco  Baby Food  H  2012-05-29 00:00:00  \
# 0         Australia and Oceania   Samoa   Cosmetics  H  2013-07-20 00:00:00
# 1                        Europe    Spain  Household  L  2012-10-21 00:00:00
# 2  Middle East and North Africa  Lebanon    Clothes  L           2012-31-09
# 3  Middle East and North Africa     Iran  Cosmetics  H           2016-15-13
# 4            Sub-Saharan Africa   Zambia     Snacks  L  2011-01-04 00:00:00
#
#    1373243.88   825738.04
# 0  2542187.82  1678540.98
# 1  2267963.02   747939.49
# 2   282562.56   579000.96
# 3  1708748.37  1128242.43
# 4   398042.40   225246.90

# %% [markdown]
# Create a dataframe **`df3`** from the third sheet of the Excel file.
# * Note that you will need to skip the first few lines

# %%
third_path = '/content/drive/MyDrive/pandas_df_prac/sample_sales3.xlsx'

# %%
df3 = pd.read_excel(third_path, sheet_name='Sample_Sales_3', skiprows=4)

# %%
df3
# Out:
#                               Region       Country        Item Type  \
# 0       Middle East and North Africa    Azerbaijan  Office Supplies
# 1                             Europe       Romania        Cosmetics
# 2  Central America and the Caribbean     Nicaragua        Beverages
# 3                 Sub-Saharan Africa          Mali          Clothes
# 4                               Asia      Malaysia           Fruits
# 5                 Sub-Saharan Africa  Sierra Leone       Vegetables
# 6                      North America        Mexico    Personal Care
# 7                 Sub-Saharan Africa    Mozambique        Household
#
#   Order Priority Order Date  Total Cost  Total Profit
# 0              M 2012-06-13  1060944.16     255151.25
# 1              H 2010-11-26  2082940.30    1375311.70
# 2              C 2011-02-05   259279.24     127722.96
# 3              M 2011-07-26    31825.92      65214.72
# 4              L 2011-11-11    43367.64      15103.47
# ...

# %% [markdown]
# Create a dataframe **`df_concat_13`** that concatenates the dataframes **`df1`** and **`df3`** on the row axis.
#
# NB: remember to reset your index!

# %%
df_concat_13 = pd.concat([df1, df3], axis=0)
df_concat_13.reset_index(drop=True)
# Out:
#                                Region                Country        Item Type  \
# 0                              Europe                 Russia  Office Supplies
# 1               Australia and Oceania                 Tuvalu        Baby Food
# 2                                   ~  Sao Tome and Principe           Fruits
# 3   Central America and the Caribbean                Grenada           Cereal
# 4                              Europe                 Russia  Office Supplies
# ..                                ...                    ...              ...
# 93                               Asia                 Brunei  Office Supplies
# 94                             Europe               Bulgaria  Office Supplies
# 95                 Sub-Saharan Africa                  Niger    Personal Care
# 96       Middle East and North Africa             Azerbaijan        Cosmetics
# 97                 Sub-Saharan Africa             The Gambia           Cereal
#
# ...

# %% [markdown]
# ## Replacing and removing

# %% [markdown]
# For dataframe **`df1`**, column name "Order Priority":
# * replace "H" with "High"
# * replace "M" with "Medium"
# * replace "L" with "Low"
#
# (Keep the dataframe name **`df1`**)
#
#
# Note: you can either write a separate line of code for each of the replacements, OR you can do all the replacements with a single line of code...

# %%
df1['Order Priority'] = df1['Order Priority'].replace(['H','M','L','C'],['High', 'Medium', 'Low', 'Constant'])
df1.reset_index(drop=True)
df1.head()
# Out:
#                               Region                Country        Item Type  \
# 0                             Europe                 Russia  Office Supplies
# 1              Australia and Oceania                 Tuvalu        Baby Food
# 2                                  ~  Sao Tome and Principe           Fruits
# 3  Central America and the Caribbean                Grenada           Cereal
# 4                             Europe                 Russia  Office Supplies
#
#   Order Priority Order Date  Total Cost Total Profit
# 0            Low 2014-05-02   933903.84            ~
# 1           High 2010-05-28  1582243.50     951410.5
# 2       Constant 2014-06-20    56065.84     19525.82
# 3       Constant 2012-08-22   328376.44    248406.36
# 4            Low 2014-05-02   933903.84            ~

# %% [markdown]
# For dataframe **`df1`**, replace all entries containing '~' with NaN values.
#
# NB: remember to import the numpy library!

# %%
import numpy as np

# %%
# Enter code here
df1.replace('~', np.nan, inplace=True)
df1.head()
# Out:
#                               Region                Country        Item Type  \
# 0                             Europe                 Russia  Office Supplies
# 1              Australia and Oceania                 Tuvalu        Baby Food
# 2                                NaN  Sao Tome and Principe           Fruits
# 3  Central America and the Caribbean                Grenada           Cereal
# 4                             Europe                 Russia  Office Supplies
#
#   Order Priority Order Date  Total Cost  Total Profit
# 0            Low 2014-05-02   933903.84           NaN
# 1           High 2010-05-28  1582243.50     951410.50
# 2       Constant 2014-06-20    56065.84      19525.82
# 3       Constant 2012-08-22   328376.44     248406.36
# 4            Low 2014-05-02   933903.84           NaN

# %% [markdown]
# For dataframe **`df1`**, remove all rows in the dataframe where there is a "C" in the "Order Priority" column.

# %%
df6 =df1[~df1['Order Priority'].isin(['Constant'])]

# %%
df6
# Out:
#                                Region                Country        Item Type  \
# 0                              Europe                 Russia  Office Supplies
# 1               Australia and Oceania                 Tuvalu        Baby Food
# 4                              Europe                 Russia  Office Supplies
# 6                  Sub-Saharan Africa                 Rwanda  Office Supplies
# 8                  Sub-Saharan Africa                 Angola        Household
# 9                  Sub-Saharan Africa                 Angola        Household
# 10                 Sub-Saharan Africa                    NaN       Vegetables
# 11                 Sub-Saharan Africa  Republic of the Congo    Personal Care
# 12                 Sub-Saharan Africa                Senegal           Cereal
# 13                               Asia             Kyrgyzstan       Vegetables
# 14                 Sub-Saharan Africa             Cape Verde          Clothes
# ...

# %% [markdown]
# Give the Order Priority of the third sample/row in this new table by using Pandas commands.

# %% [markdown]
# Are you getting an error message? Why?
#
# Fix the error by...

# %%
# Enter code here (if applicable)
third_row_priority = df1['Order Priority'][2]

# %% [markdown]
# The Order Priority of the third sample is therefore:

# %% [markdown]
# Create a dataframe **`df_cereal`**. This dataframe should only contain the rows of **`df1`** where the "Item Type" entry is "Cereal"
# * remember to reset the index

# %%
df_cereal = df1[df1['Item Type'] == 'Cereal'].reset_index(drop=True)

# %%
df_cereal
# Out:
#                               Region     Country Item Type Order Priority  \
# 0  Central America and the Caribbean     Grenada    Cereal       Constant
# 1                 Sub-Saharan Africa     Senegal    Cereal           High
# 2                 Sub-Saharan Africa  The Gambia    Cereal           High
#
#   Order Date  Total Cost  Total Profit
# 0 2012-08-22   328376.44     248406.36
# 1 2014-04-18   772106.23     584073.87
# 2 2012-06-07   247921.87     187545.03

# %% [markdown]
# Remove the column "Total Cost" and "Total Profit" in dataframe **`df1`**.
#
# (Keep the dataframe name **`df1`**)

# %%
df1.drop(columns=['Total Cost', 'Total Profit'], inplace=True)

# %%
df1
# Out:
#                                Region                Country        Item Type  \
# 0                              Europe                 Russia  Office Supplies
# 1               Australia and Oceania                 Tuvalu        Baby Food
# 2                                 NaN  Sao Tome and Principe           Fruits
# 3   Central America and the Caribbean                Grenada           Cereal
# 4                              Europe                 Russia  Office Supplies
# 5                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 6                  Sub-Saharan Africa                 Rwanda  Office Supplies
# 7               Australia and Oceania        Solomon Islands        Baby Food
# 8                  Sub-Saharan Africa                 Angola        Household
# 9                  Sub-Saharan Africa                 Angola        Household
# 10                 Sub-Saharan Africa                    NaN       Vegetables
# ...

# %% [markdown]
# Some of the entries in **`df1`** are duplicates.
# If the same "Country" and "Item type" entries appear in more than one row, only keep the **`last`** entry and remove the rest of the duplicates. Keep the name of the dataframe **`df1`**
# * remember to reset the index

# %%
df1 = df1.drop_duplicates(subset=['Country', 'Item Type'], keep='last').reset_index(drop=True)

# %%
df1
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# 5               Australia and Oceania        Solomon Islands        Baby Food
# 6                  Sub-Saharan Africa                 Angola        Household
# 7                  Sub-Saharan Africa                    NaN       Vegetables
# 8                  Sub-Saharan Africa  Republic of the Congo    Personal Care
# 9                  Sub-Saharan Africa                Senegal           Cereal
# 10                               Asia             Kyrgyzstan       Vegetables
# ...

# %% [markdown]
# ## Dates

# %% [markdown]
# Consider dataframe **`df2`**.
# Change the Order Date column to a pandas datetime, with the format: year-month-day
#
# (Keep the dataframe name **`df2`**)
#
# * remember to add code that would allow for incorrect dates to be displayed as "NaT"

# %%
# Enter code here
df2['Order Date'] = pd.to_datetime(df2['Order Date'], format="%Y-%m-%d", errors='coerce')
df2.head()
# Out:
#                          Region  Country  Item Type Order Priority Order Date  \
# 0                        Europe   Monaco  Baby Food              H 2012-05-29
# 1         Australia and Oceania   Samoa   Cosmetics              H 2013-07-20
# 2                        Europe    Spain  Household              L 2012-10-21
# 3  Middle East and North Africa  Lebanon    Clothes              L        NaT
# 4  Middle East and North Africa     Iran  Cosmetics              H        NaT
#
#    Total Cost  Total Profit
# 0  1373243.88     825738.04
# 1  2542187.82    1678540.98
# 2  2267963.02     747939.49
# 3   282562.56     579000.96
# 4  1708748.37    1128242.43

# %% [markdown]
# Remove all the rows in **`df2`** that contain NaT values in your "Order Date" column.
#
# (Keep the dataframe name **df2**)
#
# * NB: since you removed some rows, remember to reset your index!

# %%
# Enter code here
df2 = df2[df2['Order Date'].notnull()].reset_index(drop=True)
df2.head()
# Out:
#                   Region Country   Item Type Order Priority Order Date  \
# 0                 Europe  Monaco   Baby Food              H 2012-05-29
# 1  Australia and Oceania  Samoa    Cosmetics              H 2013-07-20
# 2                 Europe   Spain   Household              L 2012-10-21
# 3     Sub-Saharan Africa  Zambia      Snacks              L 2011-01-04
# 4     Sub-Saharan Africa   Kenya  Vegetables              L 2012-03-18
#
#    Total Cost  Total Profit
# 0  1373243.88     825738.04
# 1  2542187.82    1678540.98
# 2  2267963.02     747939.49
# 3   398042.40     225246.90
# 4   587135.01     407630.41

# %% [markdown]
# ## Dataframe --> CSV / Excel sheet

# %% [markdown]
# Write dataframe df1 to a csv named 'dataframe_1' and write it to the *pandas_df_prac* folder in your Drive

# %%
# Enter code here

# %% [markdown]
# Write dataframe df2 to an excel sheet named 'dataframe_2' and write it to the *pandas_df_prac* folder in your Drive

# %%
# Enter code here

# %% [markdown]
# ## Additional exercises (if time allows)

# %% [markdown]
# Have a look at dataframe df3

# %%
# Enter code here

# %% [markdown]
# Using Pandas commands, sort the Dataframe according to the Total Profit (from large to small profit)
#
# Name this dataframe **sorted_df3**

# %%
# Enter code here

# %% [markdown]
# What if we are only interested in the total cost and profit of the item types that are listed in dataframe **df3**? I.e., we want to generate a table consisting of three columns: *Item Type*, *Total Cost*, *Total Profit*
#
# The *Item Type* column should list the each distinct item type once, and the *Total Cost* and *Total Profit* columns should give a summation of the costs associated with the given item types.

# %%
# Enter code here
